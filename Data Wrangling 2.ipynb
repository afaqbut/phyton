# %%
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.shape,df.size
# Out:
# ((891, 15), 13365)

# %%
print(df)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.tail(20)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 872         0       1    male  33.0      0      0   5.0000        S   First
# 873         0       3    male  47.0      0      0   9.0000        S   Third
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 876         0       3    male  20.0      0      0   9.8458        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# ...

# %%
df.to_csv('boat.csv')

# %%
print(df)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.drop(["age","alone"], axis=1)
# Out:
#      survived  pclass     sex  sibsp  parch     fare embarked   class    who  \
# 0           0       3    male      1      0   7.2500        S   Third    man
# 1           1       1  female      1      0  71.2833        C   First  woman
# 2           1       3  female      0      0   7.9250        S   Third  woman
# 3           1       1  female      1      0  53.1000        S   First  woman
# 4           0       3    male      0      0   8.0500        S   Third    man
# ..        ...     ...     ...    ...    ...      ...      ...     ...    ...
# 886         0       2    male      0      0  13.0000        S  Second    man
# 887         1       1  female      0      0  30.0000        S   First  woman
# 888         0       3  female      1      2  23.4500        S   Third  woman
# 889         1       1    male      0      0  30.0000        C   First    man
# 890         0       3    male      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive
# ...

# %%
df.drop(["sex","class"], axis=1)
# Out:
#      survived  pclass   age  sibsp  parch     fare embarked    who  \
# 0           0       3  22.0      1      0   7.2500        S    man
# 1           1       1  38.0      1      0  71.2833        C  woman
# 2           1       3  26.0      0      0   7.9250        S  woman
# 3           1       1  35.0      1      0  53.1000        S  woman
# 4           0       3  35.0      0      0   8.0500        S    man
# ..        ...     ...   ...    ...    ...      ...      ...    ...
# 886         0       2  27.0      0      0  13.0000        S    man
# 887         1       1  19.0      0      0  30.0000        S  woman
# 888         0       3   NaN      1      2  23.4500        S  woman
# 889         1       1  26.0      0      0  30.0000        C    man
# 890         0       3  32.0      0      0   7.7500        Q    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN  Southampton    no  False
# 1         False    C    Cherbourg   yes  False
# ...

# %%
df.mean()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_812\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %% [markdown]
# ## group by

# %%
df.groupby(['alive','alone']).mean()
# Out:
#              survived    pclass        age     sibsp     parch       fare  \
# alive alone
# no    False       0.0  2.502857  27.360000  1.737143  1.034286  39.195002
#       True        0.0  2.545455  32.414234  0.000000  0.000000  14.127258
# yes   False       1.0  1.843575  25.526063  0.905028  0.888268  58.254191
#       True        1.0  2.067485  31.811538  0.000000  0.000000  37.568891
#
#              adult_male
# alive alone
# no    False    0.588571
#       True     0.925134
# yes   False    0.134078
#       True     0.392638

# %%
df.groupby(['sex','age']).mean()
# Out:
#               survived  pclass  sibsp  parch       fare  adult_male  alone
# sex    age
# female 0.75   1.000000     3.0    2.0    1.0  19.258300         0.0    0.0
#        1.00   1.000000     3.0    0.5    1.5  13.437500         0.0    0.0
#        2.00   0.333333     2.5    1.5    1.5  43.245833         0.0    0.0
#        3.00   0.500000     2.5    2.0    1.5  31.327100         0.0    0.0
#        4.00   1.000000     2.6    0.8    1.2  22.828340         0.0    0.0
# ...                ...     ...    ...    ...        ...         ...    ...
# male   70.00  0.000000     1.5    0.5    0.5  40.750000         1.0    0.5
#        70.50  0.000000     3.0    0.0    0.0   7.750000         1.0    1.0
#        71.00  0.000000     1.0    0.0    0.0  42.079200         1.0    1.0
#        74.00  0.000000     3.0    0.0    0.0   7.775000         1.0    1.0
#        80.00  1.000000     1.0    0.0    0.0  30.000000         1.0    1.0
#
# [145 rows x 7 columns]

# %%
df[(df['survived']>1) | (df['age']<5)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 7           0       3    male  2.00      3      1   21.0750        S   Third
# 10          1       3  female  4.00      1      1   16.7000        S   Third
# 16          0       3    male  2.00      4      1   29.1250        Q   Third
# 43          1       2  female  3.00      1      2   41.5792        C  Second
# 63          0       3    male  4.00      3      2   27.9000        S   Third
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 119         0       3  female  2.00      4      2   31.2750        S   Third
# 164         0       3    male  1.00      4      1   39.6875        S   Third
# 171         0       3    male  4.00      4      1   29.1250        Q   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
# ...

# %%
df[df['age']<18].groupby(['sex','class']).mean()
# Out:
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.875000     1.0  14.125000  0.500000  0.875000  104.083337
#        Second  1.000000     2.0   8.333333  0.583333  1.083333   26.241667
#        Third   0.542857     3.0   8.428571  1.571429  1.057143   18.727977
# male   First   1.000000     1.0   8.230000  0.500000  2.000000  116.072900
#        Second  0.818182     2.0   4.757273  0.727273  1.000000   25.659473
#        Third   0.232558     3.0   9.963256  2.069767  1.000000   22.752523
#
#                adult_male     alone
# sex    class
# female First     0.000000  0.125000
#        Second    0.000000  0.166667
#        Third     0.000000  0.228571
# male   First     0.250000  0.000000
#        Second    0.181818  0.181818
#        Third     0.348837  0.232558

# %%
df.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# ...

# %%
df.min
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# ...

# %%
df.iloc[:,:]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[(df['age']<20) & (df['sex'] == 'male')]
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked   class  \
# 7           0       3  male   2.0      3      1   21.0750        S   Third
# 16          0       3  male   2.0      4      1   29.1250        Q   Third
# 27          0       1  male  19.0      3      2  263.0000        S   First
# 50          0       3  male   7.0      4      1   39.6875        S   Third
# 59          0       3  male  11.0      5      2   46.9000        S   Third
# ..        ...     ...   ...   ...    ...    ...       ...      ...     ...
# 841         0       2  male  16.0      0      0   10.5000        S  Second
# 844         0       3  male  17.0      0      0    8.6625        S   Third
# 850         0       3  male   4.0      4      2   31.2750        S   Third
# 869         1       3  male   4.0      1      1   11.1333        S   Third
# 877         0       3  male  19.0      0      0    7.8958        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## Handling Missing Data

# %%
df.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.drop_duplicates()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.sample()
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked   class  \
# 432         1       2  female  42.0      1      0  26.0        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 432  woman       False  NaN  Southampton   yes  False

# %%
df.sample(n=10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 314         0       2    male  43.0      1      1  26.2500        S  Second
# 423         0       3  female  28.0      1      1  14.4000        S   Third
# 156         1       3  female  16.0      0      0   7.7333        Q   Third
# 576         1       2  female  34.0      0      0  13.0000        S  Second
# 510         1       3    male  29.0      0      0   7.7500        Q   Third
# 876         0       3    male  20.0      0      0   9.8458        S   Third
# 805         0       3    male  31.0      0      0   7.7750        S   Third
# 482         0       3    male  50.0      0      0   8.0500        S   Third
# 533         1       3  female   NaN      0      2  22.3583        C   Third
# 182         0       3    male   9.0      4      2  31.3875        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 314    man        True  NaN  Southampton    no  False
# ...

# %%
df.nsmallest('age')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 df.nsmallest('age')
#
# TypeError: nsmallest() missing 1 required positional argument: 'columns'

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %% [markdown]
# ## summrize Data

# %%
df.shape
# Out:
# (891, 15)

# %%
import pandas as pd

# %%
df['age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: age, Length: 88, dtype: int64

# %%
df.shape
# Out:
# (891, 15)

# %%
df['class'].nunique()
# Out:
# 3

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ## Windows

# %%
df.expanding('fare')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 df.expanding('fare')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:11300, in NDFrame.expanding(self, min_periods, center, axis, method)
#   11297 else:
#   11298     center = False
# > 11300 return Expanding(
#   11301     self, min_periods=min_periods, center=center, axis=axis, method=method
#   11302 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\window\expanding.py:132, in Expanding.__init__(self, obj, min_periods, center, axis, method, selection)
#     123 def __init__(
#     124     self,
#     125     obj: NDFrame,
#    (...)
#     130     selection=None,
#     131 ):
# --> 132     super().__init__(
#     133         obj=obj,
#     134         min_periods=min_periods,
#     135         center=center,
#     136         axis=axis,
# ...

# %%
df.rolling('age')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 df.rolling('age')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:11269, in NDFrame.rolling(self, window, min_periods, center, win_type, on, axis, closed, method)
#   11256 if win_type is not None:
#   11257     return Window(
#   11258         self,
#   11259         window=window,
#    (...)
#   11266         method=method,
#   11267     )
# > 11269 return Rolling(
#   11270     self,
#   11271     window=window,
#   11272     min_periods=min_periods,
#   11273     center=center,
#   11274     win_type=win_type,
#   11275     on=on,
#   11276     axis=axis,
#   11277     closed=closed,
#   11278     method=method,
#   11279 )
#
# ...

# %% [markdown]
# ## Ploting

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.scatter(x='age',y='fare')
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
df.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## subset rows

# %%
df[df.age > 5]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.sample(frac=0.5)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 467         0       1    male  56.0      0      0  26.5500        S  First
# 354         0       3    male   NaN      0      0   7.2250        C  Third
# 324         0       3    male   NaN      8      2  69.5500        S  Third
# 477         0       3    male  29.0      1      0   7.0458        S  Third
# 585         1       1  female  18.0      0      2  79.6500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 283         1       3    male  19.0      0      0   8.0500        S  Third
# 335         0       3    male   NaN      0      0   7.8958        S  Third
# 719         0       3    male  33.0      0      0   7.7750        S  Third
# 28          1       3  female   NaN      0      0   7.8792        Q  Third
# 828         1       3    male   NaN      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.sample(n=10)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 822         0       1    male  38.0      0      0    0.0000        S   First
# 721         0       3    male  17.0      1      0    7.0542        S   Third
# 772         0       2  female  57.0      0      0   10.5000        S  Second
# 515         0       1    male  47.0      0      0   34.0208        S   First
# 398         0       2    male  23.0      0      0   10.5000        S  Second
# 155         0       1    male  51.0      0      1   61.3792        C   First
# 317         0       2    male  54.0      0      0   14.0000        S  Second
# 209         1       1    male  40.0      0      0   31.0000        C   First
# 700         1       1  female  18.0      1      0  227.5250        C   First
# 758         0       3    male  34.0      0      0    8.0500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 822    man        True  NaN  Southampton    no   True
# ...

# %%
df.nsmallest(20,'fare')
# Out:
#      survived  pclass   sex   age  sibsp  parch    fare embarked   class  who  \
# 179         0       3  male  36.0      0      0  0.0000        S   Third  man
# 263         0       1  male  40.0      0      0  0.0000        S   First  man
# 271         1       3  male  25.0      0      0  0.0000        S   Third  man
# 277         0       2  male   NaN      0      0  0.0000        S  Second  man
# 302         0       3  male  19.0      0      0  0.0000        S   Third  man
# 413         0       2  male   NaN      0      0  0.0000        S  Second  man
# 466         0       2  male   NaN      0      0  0.0000        S  Second  man
# 481         0       2  male   NaN      0      0  0.0000        S  Second  man
# 597         0       3  male  49.0      0      0  0.0000        S   Third  man
# 633         0       1  male   NaN      0      0  0.0000        S   First  man
# 674         0       2  male   NaN      0      0  0.0000        S  Second  man
# ...

# %% [markdown]
# ## subset veriable colums

# %%
df[['age','fare','class']]
# Out:
#       age     fare   class
# 0    22.0   7.2500   Third
# 1    38.0  71.2833   First
# 2    26.0   7.9250   Third
# 3    35.0  53.1000   First
# 4    35.0   8.0500   Third
# ..    ...      ...     ...
# 886  27.0  13.0000  Second
# 887  19.0  30.0000   First
# 888   NaN  23.4500   Third
# 889  26.0  30.0000   First
# 890  32.0   7.7500   Third
#
# [891 rows x 3 columns]

# %%
df['embark_town']
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 886    Southampton
# 887    Southampton
# 888    Southampton
# 889      Cherbourg
# 890     Queenstown
# Name: embark_town, Length: 891, dtype: object

# %%
df.filter(regex='pclass')
# Out:
#      pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]

# %%
df.iloc[10:20]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 17         1       2    male   NaN      0      0  13.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
# 19         1       3  female   NaN      0      0   7.2250        C   Third
#
#       who  adult_male deck  embark_town alive  alone
# 10  child       False    G  Southampton   yes  False
# ...

# %%
df.iloc[:, [1, 2, 5]]
# Out:
#      pclass     sex  parch
# 0         3    male      0
# 1         1  female      0
# 2         3  female      0
# 3         1  female      0
# 4         3    male      0
# ..      ...     ...    ...
# 886       2    male      0
# 887       1  female      0
# 888       3  female      2
# 889       1    male      0
# 890       3    male      0
#
# [891 rows x 3 columns]

# %%
df.loc[:,'age':'class']
# Out:
#       age  sibsp  parch     fare embarked   class
# 0    22.0      1      0   7.2500        S   Third
# 1    38.0      1      0  71.2833        C   First
# 2    26.0      0      0   7.9250        S   Third
# 3    35.0      1      0  53.1000        S   First
# 4    35.0      0      0   8.0500        S   Third
# ..    ...    ...    ...      ...      ...     ...
# 886  27.0      0      0  13.0000        S  Second
# 887  19.0      0      0  30.0000        S   First
# 888   NaN      1      2  23.4500        S   Third
# 889  26.0      0      0  30.0000        C   First
# 890  32.0      0      0   7.7500        Q   Third
#
# [891 rows x 6 columns]

# %%
df.iat[1,2]
# Out:
# 'female'

# %%
df.at[4, 'class']
# Out:
# 'Third'
